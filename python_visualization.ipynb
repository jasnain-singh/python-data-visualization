# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Students_performance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Statistics of the data
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# Writing score vs math score
plt.figure (figsize=(10,6))
plt.scatter(df["math score"],df["writing score"],marker="*",color="y")
plt.xlabel("Math Score")
plt.ylabel("Writing Score")
plt.title("Scatter plot [Math score VS writing score]")
# Out:
# Text(0.5, 1.0, 'Scatter plot [Math score VS writing score]')

# %%
plt.figure(figsize=(14,10))
plt.scatter(df["math score"], df["writing score"], marker=".", color="r", label= "math vs writing")
plt.scatter(df["math score"], df["reading score"], marker="2", color="c", label= "math vs reading")
plt.xlabel("")
plt.ylabel("")
plt.title("")
plt.legend()

# %% [markdown]
# # Histogram
# * math score
# * reading score
# * writing score
# * apply bins = 5,7,10

# %%
plt.hist(df["math score"], bins=10, color="m", edgecolor="k")
plt.xlabel("Math Score")
plt.title("Histogram of Math Score")
# Out:
# Text(0.5, 1.0, 'Histogram of Math Score')

# %% [markdown]
# # Bar Plot:

# %%
plt.hist(df["writing score"], bins=7, color="c", edgecolor="k")
plt.xlabel("Writing Score")
plt.title("Histogram of Writing Score")
# Out:
# Text(0.5, 1.0, 'Histogram of Writing Score')

# %%
plt.hist(df["reading score"], bins=5, color="r", edgecolor="k")
plt.xlabel("Reading Score")
plt.title("Histogram of Reading Score")
# Out:
# Text(0.5, 1.0, 'Histogram of Reading Score')

# %%
df["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
df["gender"].value_counts().plot(kind="bar", color="y", edgecolor="k")
plt.title("Gender Bar Chart")
# Out:
# Text(0.5, 1.0, 'Gender Bar Chart')

# %%
df["parental level of education"].value_counts().plot(kind="bar", color="c", edgecolor="k")
plt.title("Level of Edu Bar Chart")
# Out:
# Text(0.5, 1.0, 'Level of Edu Bar Chart')

# %%
df["race/ethnicity"].value_counts().plot(kind="bar", color="r", edgecolor="k")
plt.title("Ethnicity Bar Chart")
# Out:
# Text(0.5, 1.0, 'Ethnicity Bar Chart')

# %%
df["lunch"].value_counts().plot(kind="bar", color="g", edgecolor="k")
plt.title("Lunch Bar Chart")
# Out:
# Text(0.5, 1.0, 'Lunch Bar Chart')

# %% [markdown]
# # Box Plot:
# * math score
# * writing score
# * reading score

# %%
plt.figure(figsize=(14,10))
plt.boxplot(df["math score"])
plt.show()

# %% [markdown]
# # Data Visualization

# %%
ds = pd.read_csv("gas_prices.csv")
ds
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %% [markdown]
# ### Line Chart
# 1. Line chart of Year vs Australia Canada France (combined)
# 2. Line chart of Year vs Germany Italy Japan (combined)
# 3. Line chart of Year vs Mexico South Korea UK USA (combined)

# %%
plt.figure(figsize=(12,8))
plt.plot(ds["Year"],ds["Australia"], marker="2", color="r", label="Australia")
plt.plot(ds["Year"],ds["Canada"], marker=".", color="c", label="Canada")
plt.plot(ds["Year"],ds["France"], marker="o", color="y", label="France")
plt.xlabel("Year")
plt.ylabel("Australia - Canada - France")
plt.title("Year vs Australia Canada France")
plt.legend()

# %%
plt.figure(figsize=(12,8))
plt.plot(ds["Year"],ds["Germany"], marker="2", color="r", label="Germany")
plt.plot(ds["Year"],ds["Italy"], marker=".", color="c", label="Italy")
plt.plot(ds["Year"],ds["Japan"], marker="o", color="y", label="Japan")
plt.xlabel("Year")
plt.ylabel("Germany - Italy - Japan")
plt.title("Year vs Germany Italy Japan")
plt.legend()

# %%
plt.figure(figsize=(12,8))
plt.plot(ds["Year"],ds["Mexico"], marker="2", color="r", label="Mexico")
plt.plot(ds["Year"],ds["South Korea"], marker=".", color="c", label="South Korea")
plt.plot(ds["Year"],ds["UK"], marker="s", color="y", label="UK")
plt.plot(ds["Year"],ds["USA"], marker="o", color="b", label="USA")
plt.xlabel("Year")
plt.ylabel("Mexico - South Korea - UK - USA")
plt.title("Year vs Mexico South Korea UK USA")
plt.legend()

# %%
# changing the figure size
# changing the front size of the figure

plt.figure(figsize=(10,8))
plt.plot(ds.Year, ds.USA, '*-', label='USA', color='r')
plt.plot(ds.Year, ds.Australia, '*-', label='Australia', color='g')
plt.plot(ds.Year, ds.UK, '*-', label='UK', color='b')
plt.plot(ds.Year, ds.Japan, '*-', label='Japan', color='y')
#marker = *, line = -, color = red

plt.title('Gas Prices over Year(USD)', fontdict={'fontweight':'bold', 'fontsize':18})
# changing the title font size and font type

plt.xlabel('Year', fontdict={'fontweight':'bold', 'fontsize':12})
plt.ylabel('Price', fontdict={'fontweight':'bold', 'fontsize':12})
plt.legend()
#saving the image in particular format(png,jpg) resolution dpi == 100

plt.savefig('Gas Prices over Year(USD).png', dpi=100)
